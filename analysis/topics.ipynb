# %%
import os
from bertopic import BERTopic
from umap import UMAP
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

# %%
def get_topic_info(topic_model: BERTopic, text_list: list[str], dataframe: pd.DataFrame):
    doc_info = topic_model.get_document_info(text_list)
    doc_info["class_label"] = dataframe["class_label"]

    # Calculate Yes/No class counts per topic
    topic_class_counts = doc_info.groupby(['Topic', 'Name'])['class_label'].value_counts().unstack(fill_value=0).reset_index()
    topic_class_counts["count"] = topic_class_counts["Yes"] + topic_class_counts["No"]
    topic_class_counts["pos_ratio"] = topic_class_counts["Yes"] / (topic_class_counts["Yes"] + topic_class_counts["No"])

    # Add class counts to topic info
    topic_info = topic_model.get_topic_info()
    topic_info["No"] = topic_class_counts["No"]
    topic_info["Yes"] = topic_class_counts["Yes"]
    topic_info["pos_ratio"] = topic_class_counts["pos_ratio"]

    return topic_info

# %%
def reduce_topic(topic_model: BERTopic, topic_id, text_list, topics, threshold, strategy, embeddings=None):
    old_topic_info = topic_model.get_topic_info()
    new_topics = topic_model.reduce_outliers(text_list, topics, threshold=threshold, strategy=strategy, embeddings=embeddings, topic_id=topic_id)
    topic_model.update_topics(docs=text_list, topics=new_topics)
    new_topic_info = topic_model.get_topic_info()
    
    # How many docs changed topic
    num_reassigned = old_topic_info.loc[old_topic_info["Topic"] == topic_id]["Count"] - new_topic_info.loc[new_topic_info["Topic"] == topic_id]["Count"]
    num_reassigned = num_reassigned.iloc[0]
    
    # How many target topics did the docs change to
    num_changed = (old_topic_info["Count"] != new_topic_info["Count"]).sum() - (1 if num_reassigned != 0 else 0)
    old_topic_name = (old_topic_info.loc[old_topic_info["Topic"] == topic_id]["Name"]).iloc[0]

    print(f"Reassigned {num_reassigned} documents from \"{old_topic_name}\" to {num_changed} new topics")

    return new_topics

# %%
df_train = pd.read_csv("../data/CT24_checkworthy_english/train.csv")
df_dev = pd.read_csv("../data/CT24_checkworthy_english/dev.csv")
df_dev_test = pd.read_csv("../data/CT24_checkworthy_english/dev-test.csv")
df_test_gold = pd.read_csv("../data/CT24_checkworthy_english/test-gold.csv")
df = pd.concat([df_train, df_dev, df_dev_test, df_test_gold], ignore_index=True)
text_list = df.Text.to_list()

# %%
# Pre-calculate embeddings
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
style_embedding_model = SentenceTransformer("StyleDistance/styledistance")
embeddings = embedding_model.encode(text_list, show_progress_bar=True)
style_embeddings = style_embedding_model.encode(text_list, show_progress_bar=True)
# Out:
# ...
# Batches:   0%|          | 0/756 [00:00<?, ?it/s]

# %%
umap_model = UMAP(n_neighbors=30, n_components=5, min_dist=0.0, metric='cosine', random_state=42)
vectorizer_model = CountVectorizer(stop_words="english", min_df=2, ngram_range=(1, 2))
topic_model = BERTopic(min_topic_size=50, umap_model=umap_model, vectorizer_model=vectorizer_model)
topics, probs = topic_model.fit_transform(documents=text_list, embeddings=embeddings)

# %%
get_topic_info(topic_model=topic_model, text_list=text_list, dataframe=df)
# Out:
#     Topic  Count                                            Name  \
# 0      -1  12844                   -1_people_think_going_country
# 1       0   1280            0_health_care_social security_social
# 2       1    756                         1_tax_taxes_tax cut_cut
# 3       2    542               2_jobs_unemployment_million_small
# 4       3    532             3_schools_education_school_teachers
# ..    ...    ...                                             ...
# 63     62     56      62_africa_southern africa_southern_african
# 64     63     55              63_test_testing_litmus test_litmus
# 65     64     54           64_dole_senator dole_senator_bob dole
# 66     65     50        65_peace_world peace_peaceful_kept peace
# 67     66     50  66_recession_depression_great depression_worst
#
#                                        Representation  \
# 0   [people, think, going, country, know, presiden...
# 1   [health, care, social security, social, medica...
# ...

# %%
#topic_model.visualize_heatmap(n_clusters=20)

# %%
# Manually select similar topics and merge them
merge_topics = [
    [12, 14, 27, 34, 66, 53] # economy
]
topic_model.merge_topics(docs=text_list, topics_to_merge=merge_topics)
# Update topics list after merge
topics = topic_model.get_document_info(docs=text_list)["Topic"].to_list()

# %%
# Reduce outliers
topics = reduce_topic(
    topic_model=topic_model,
    topic_id=-1,
    text_list=text_list,
    topics=topics,
    threshold=0.4,
    strategy="embeddings",
    embeddings=embeddings)
# Out:
# 2025-12-03 10:07:14,934 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
# Reassigned 9631 documents from "-1_people_think_going_country" to 62 new topics

# %%
topic_info = get_topic_info(topic_model=topic_model, text_list=text_list, dataframe=df)
topic_info
# Out:
#     Topic  Count                               Name  \
# 0      -1   3213                   -1_you_he_it_was
# 1       0   1353      0_health_care_social_medicare
# 2       1    981                1_tax_taxes_cut_for
# 3       2   1407  2_economy_budget_spending_billion
# 4       3    841  3_jobs_unemployment_million_small
# ..    ...    ...                                ...
# 58     57    134     57_mistake_wrong_made_mistakes
# 59     58    220               58_plan_my_plans_you
# 60     59     73       59_test_testing_tests_litmus
# 61     60     65          60_dole_senator_doles_bob
# 62     61    224          61_peace_world_freedom_we
#
#                                        Representation  \
# 0   [you, he, it, was, and, the, of, they, that, t...
# 1   [health, care, social, medicare, insurance, se...
# 2   [tax, taxes, cut, for, cuts, the, increase, pe...
# 3   [economy, budget, spending, billion, deficit, ...
# 4   [jobs, unemployment, million, small, business,...
# ...

# %%
#topic_model.visualize_topics()

# %%
#topic_model.visualize_documents(text_list, embeddings=embeddings, width=1000, hide_document_hover=False, hide_annotations=True)

# %%
df["Topic"] = topics

# %%
# Explore a specific topic id
topic_id = 61
print("Topic name: ", topic_info[topic_info["Topic"] == topic_id]["Name"].to_list()[0])
print("Examples:")
print("\n".join(topic_model.get_representative_docs(topic_id)))
print("Yes ratio: ", topic_info[topic_info["Topic"] == topic_id]["pos_ratio"].to_list()[0])
df[df["Topic"] == topic_id]
# Out:
# Topic name:  61_peace_world_freedom_we
# Examples:
# World peace is important, and we have enhanced the peace.
# And that's how best it is to keep the peace.
# He talks about peace and I'm thankful for peace.
# Yes ratio:  0.07142857142857142
#        Sentence_id                                               Text  \
# 23            3187  What is more moral than peace, and the United ...
# 42           26856  If we do those things we will build that bridg...
# 194          12467  I would like to unite this country to get an a...
# 225          12673  And when we are strong and when we are first, ...
# 421          12516  How can we extend freedom - extend it without ...
# ...            ...                                                ...
# 23178        15426  And we must extend the benefits of our own com...
# 23202        15646  You have to learn from experience that making ...
# 23278        16410  Working together, we can do wonderful things f...
# ...

# %%
# Manually identify unspecific topics containing samples that should be members of more specific topics
# Apply "outlier" reduction to these topics with appropriate threshold
# Merge the remaining samples in the unspecific topics and outliers into a "unspecific" category

# Topics containing samples that should be members of more specific topics
topics_to_dissolve = [5, 7, 9, 15, 21, 25, 34, 37, 38, 39, 40, 54, 58, 59, 61]
# Topics that should be merged into an "unspecific" topic class
unspecific_topics = []

# %%
for tid in topics_to_dissolve:
    topics = reduce_topic(
        topic_model=topic_model,
        topic_id=tid,
        text_list=text_list,
        topics=topics,
        threshold=0.7,
        strategy="embeddings",
        embeddings=embeddings)
# Out:
# 2025-12-03 10:07:16,193 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
# 2025-12-03 10:07:16,501 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
# Reassigned 18 documents from "5_do_we_to_going" to 2 new topics
# ...

# %%
# Insert topic ids and embedding ids
df["Topic"] = topics
df["embedding_id"] = df.index

# %%
topic_info = get_topic_info(topic_model=topic_model, text_list=text_list, dataframe=df)
topic_info
topic_info.sort_values(by=["Count"], ascending=False)
# Out:
#     Topic  Count                               Name  \
# 0      -1   3213                   -1_you_he_it_was
# 3       2   1407  2_economy_budget_spending_billion
# 1       0   1353      0_health_care_social_medicare
# 6       5    994                   5_do_we_to_going
# 2       1    981                1_tax_taxes_cut_for
# ..    ...    ...                                ...
# 37     36    108      36_romney_governor_romneys_he
# 45     44    102     44_mccain_senator_mccains_john
# 56     55     86                  55_ford_mr_uh_has
# 54     53     75    53_islands_formosa_quemoy_matsu
# 60     59     73       59_test_testing_tests_litmus
#
#                                        Representation  \
# 0   [you, he, it, was, and, the, of, they, that, t...
# 3   [economy, budget, spending, billion, deficit, ...
# 1   [health, care, social, medicare, insurance, se...
# 6   [do, we, to, going, it, were, can, what, weve,...
# 2   [tax, taxes, cut, for, cuts, the, increase, pe...
# ...

# %%
# Select which topics will end up in the final dataset
topic_selection = [2, 0, 1, 3, 16, 4, 6, 11, 13, 10, 12, 31, 26, 51, 18]
len(topic_selection)
# Out:
# 15

# %%
topic_info_selection = topic_info[topic_info["Topic"].isin(topic_selection)]
topic_info_selection
# Out:
#     Topic  Count                                 Name  \
# 1       0   1353        0_health_care_social_medicare
# 2       1    981                  1_tax_taxes_cut_for
# 3       2   1407    2_economy_budget_spending_billion
# 4       3    841    3_jobs_unemployment_million_small
# 5       4    611  4_education_schools_school_teachers
# 7       6    479                6_energy_oil_coal_gas
# 11     10    395         10_soviet_russia_union_putin
# 12     11    423           11_israel_east_middle_isis
# 13     12    384   12_nuclear_weapons_missiles_atomic
# 14     13    397          13_law_crime_police_justice
# 17     16    682           16_military_troops_our_war
# 19     18    262       18_trade_deals_free_agreements
# 27     26    284    26_afghanistan_bin_laden_pakistan
# 32     31    362       31_election_campaign_vote_this
# 52     51    278            51_saddam_hussein_he_iraq
#
#                                        Representation  \
# ...

# %%
# Reduce the topic list to the n most occuring
num_topics = 7
top_n_topics = topic_info_selection.nlargest(num_topics, "Count")
top_n_topics
# Out:
#     Topic  Count                                 Name  \
# 3       2   1407    2_economy_budget_spending_billion
# 1       0   1353        0_health_care_social_medicare
# 2       1    981                  1_tax_taxes_cut_for
# 4       3    841    3_jobs_unemployment_million_small
# 17     16    682           16_military_troops_our_war
# 5       4    611  4_education_schools_school_teachers
# 7       6    479                6_energy_oil_coal_gas
#
#                                        Representation  \
# 3   [economy, budget, spending, billion, deficit, ...
# 1   [health, care, social, medicare, insurance, se...
# 2   [tax, taxes, cut, for, cuts, the, increase, pe...
# 4   [jobs, unemployment, million, small, business,...
# 17  [military, troops, our, war, we, forces, to, a...
# 5   [education, schools, school, teachers, college...
# 7   [energy, oil, coal, gas, production, we, our, ...
#
#                                   Representative_Docs   No  Yes  pos_ratio
# ...

# %%
df_filtered = df[df["Topic"].isin(top_n_topics["Topic"])]
df_filtered["Topic_Name"] = df_filtered["Topic"].map(topic_info.set_index("Topic")["Name"])

# %%
# Find minimum count of positive and negative samples per topic
min_pos_count = df_filtered[df_filtered["class_label"] == "Yes"].groupby("Topic_Name").size().min()
min_neg_count = df_filtered[df_filtered["class_label"] == "No"].groupby("Topic_Name").size().min()

# Sample positive and negative samples for each topic to the minimum count
df_pos_balanced = (
    df_filtered[df_filtered["class_label"] == "Yes"]
    .groupby("Topic_Name")
    .apply(lambda x: x.sample(n=min_pos_count, random_state=42))
    .reset_index(drop=True)
)
df_neg_balanced = (
    df_filtered[df_filtered["class_label"] == "No"]
    .groupby("Topic_Name")
    .apply(lambda x: x.sample(n=min_neg_count, random_state=42))
    .reset_index(drop=True)
)

# Concatenate balanced positive and negative samples
df_balanced = pd.concat([df_pos_balanced, df_neg_balanced]).reset_index(drop=True)

print(df_balanced.groupby("Topic_Name")["class_label"].value_counts().unstack(fill_value=0))
# Out:
# class_label                           No  Yes
# Topic_Name
# 0_health_care_social_medicare        292  156
# 16_military_troops_our_war           292  156
# 1_tax_taxes_cut_for                  292  156
# 2_economy_budget_spending_billion    292  156
# 3_jobs_unemployment_million_small    292  156
# 4_education_schools_school_teachers  292  156
# 6_energy_oil_coal_gas                292  156
# /tmp/ipykernel_5757/2672282910.py:9: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# /tmp/ipykernel_5757/2672282910.py:15: DeprecationWarning:
#
# ...

# %%
unique_topic_names = df_balanced["Topic_Name"].unique()
print(unique_topic_names)
# Out:
# ['0_health_care_social_medicare' '16_military_troops_our_war'
#  '1_tax_taxes_cut_for' '2_economy_budget_spending_billion'
#  '3_jobs_unemployment_million_small' '4_education_schools_school_teachers'
#  '6_energy_oil_coal_gas']

# %%
# Rename topics
name_map = {
    '2_economy_budget_spending_billion': "economy",
    '1_tax_taxes_cut_for': "tax",
    '0_health_care_social_medicare': "health",
    '4_education_schools_school_teachers': "education",
    '16_military_troops_our_war': "military",
    '6_energy_oil_coal_gas': "energy",
    '3_jobs_unemployment_million_small': "employment"
}

df_balanced["Topic_Name"] = df_balanced["Topic_Name"].map(name_map)

# %%
# Reduce all topics to the same sample count as the smallest topic
# min_count = top_n_topics["Count"].min()
# df_balanced = (
#     df_filtered.groupby("Topic")
#     .apply(lambda x: x.sample(n=min_count, random_state=42))
#     .reset_index(drop=True)
# )

# %%
import glob

synth_dir = "../generate/sequences/experiment_003/economy"
csv_files = glob.glob(os.path.join(synth_dir, "economy_*.csv"))
economy_dfs = []
for file in csv_files:
    df_economy = pd.read_csv(file)
    df_economy = df_economy[df_economy["context"].notna() & (df_economy["context"] != "")]
    economy_dfs.append(df_economy)

df_synth = pd.concat(economy_dfs, ignore_index=True)
df_synth["Topic_Name"] = df_synth["topic"]
df_synth["embedding_id"] = df_synth.index

# %%
synth_text_list = df_synth.Text.to_list()
synth_embeddings = embedding_model.encode(synth_text_list, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/69 [00:00<?, ?it/s]

# %%
topic_similarity_matrix = pd.DataFrame(
    data=np.nan,
    index=name_map.values(),
    columns=name_map.values()
)
topic_style_similarity_matrix = pd.DataFrame(
    data=np.nan,
    index=name_map.values(),
    columns=name_map.values()
)
topic_synth_similarity_matrix = pd.DataFrame(
    data=np.nan,
    index=name_map.values(),
    columns=name_map.values()
)

for topic_a in topic_similarity_matrix.index:
    for topic_b in topic_similarity_matrix.columns:
        # Get embedding indices for each topic
        idx_a = df_balanced[df_balanced["Topic_Name"] == topic_a]["embedding_id"].values
        idx_b = df_balanced[df_balanced["Topic_Name"] == topic_b]["embedding_id"].values
        synth_idx_b = df_synth[df_synth["Topic_Name"] == topic_b]["embedding_id"].values
        emb_a = embeddings[idx_a]
        emb_b = embeddings[idx_b]
        style_emb_a = style_embeddings[idx_a]
        style_emb_b = style_embeddings[idx_b]
        synth_emb_b = synth_embeddings[synth_idx_b]
        # Calculate mean similarity between all pairs
        sim_matrix = embedding_model.similarity(emb_a, emb_b)
        style_sim_matrix = style_embedding_model.similarity(style_emb_a, style_emb_b)
        synth_sim_matrix = embedding_model.similarity(emb_a, synth_emb_b) # Similarity from synth embeddings to real embeddings
        mean_sim = sim_matrix.mean().cpu().item()
        mean_style_sim = style_sim_matrix.mean().cpu().item()
        mean_synth_sim = synth_sim_matrix.mean().cpu().item()
        topic_similarity_matrix.loc[topic_a, topic_b] = mean_sim
        topic_style_similarity_matrix.loc[topic_a, topic_b] = mean_style_sim
        topic_synth_similarity_matrix.loc[topic_a, topic_b] = mean_synth_sim

# %%
#topic_similarity_matrix.to_csv("../data/CT24_checkworthy_english/topic_correlation/similarity.csv", index=True)
#topic_style_similarity_matrix.to_csv("../data/CT24_checkworthy_english/topic_correlation/style_similarity.csv", index=True)
#topic_synth_similarity_matrix.to_csv("../data/CT24_checkworthy_english/topic_correlation/synth_similarity.csv", index=True)

# %%
df_balanced = df_balanced.drop(columns=["Topic", "embedding_id"])

# %%
# Adjustable split ratios
train_ratio = 0.7
dev_ratio = 0.1
test_ratio = 0.2

# Store splits
train_list = []
dev_list = []
test_list = []

# Split topic-wise
for topic in df_balanced["Topic_Name"].unique():
    topic_df = df_balanced[df_balanced["Topic_Name"] == topic]
    topic_df = topic_df.rename(columns={"Topic_Name": "topic"})
    train_df, temp_df = train_test_split(topic_df, train_size=train_ratio, random_state=42, shuffle=True)
    dev_df, test_df = train_test_split(temp_df, train_size=dev_ratio/(dev_ratio + test_ratio), random_state=42, shuffle=True)
    train_list.append(train_df)
    dev_list.append(dev_df)
    test_list.append(test_df)

df_train_split = pd.concat(train_list)
df_dev_split = pd.concat(dev_list)
df_test_split = pd.concat(test_list)

# %%
#Save datasets
dest_path = "../data/CT24_checkworthy_english/topic_correlation"
df_train_split.to_csv(os.path.join(dest_path, "train.csv"), index=False)
df_dev_split.to_csv(os.path.join(dest_path, "dev.csv"), index=False)
df_test_split.to_csv(os.path.join(dest_path, "test.csv"), index=False)

# # For each topic create a train dataset excluding that topic
# for topic_name in unique_topic_names:
#     excluded_df = df_train_split[df_train_split["Topic_Name"] != topic_name]
#     excluded_df.to_csv(os.path.join(dest_path, f"train_sans_{topic_name}.csv"), index=False)

# # Also create a train set containing all topics
# df_train_split.to_csv(os.path.join(dest_path, f"train_all_topics.csv"), index=False)

# %%
# Calculate the ratio of "Yes" vs "No" samples for each topic in df_test_split
pos_neg_ratio = df_test_split.groupby("topic")["class_label"].value_counts(normalize=True).unstack().fillna(0)
pos_neg_ratio["pos_ratio"] = pos_neg_ratio.get("Yes", 0)
pos_neg_ratio["neg_ratio"] = pos_neg_ratio.get("No", 0)
pos_neg_ratio["sample_count"] = df_test_split.groupby("topic")["class_label"].size()
pos_neg_ratio[["pos_ratio", "neg_ratio", "sample_count"]]
# Out:
# class_label  pos_ratio  neg_ratio  sample_count
# topic
# economy       0.377778   0.622222            90
# education     0.377778   0.622222            90
# employment    0.377778   0.622222            90
# energy        0.377778   0.622222            90
# health        0.377778   0.622222            90
# military      0.377778   0.622222            90
# tax           0.377778   0.622222            90

# %%
df_balanced.groupby("Topic_Name").size().sort_values(ascending=False)
# Out:
# Topic_Name
# economy       448
# education     448
# employment    448
# energy        448
# health        448
# military      448
# tax           448
# dtype: int64
