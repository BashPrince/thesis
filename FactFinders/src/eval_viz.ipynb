# %%
import os
import pandas as pd

# Folder containing the CSV files
results_folder = 'results'

# Load all CSV files containing 'eval_dev_test' into a dictionary of DataFrames
dataframes = {}
for file in os.listdir(results_folder):
    if 'eval_dev_test' in file and file.endswith('.csv'):
        file_path = os.path.join(results_folder, file)
        key = file.split('_', 1)[0]  # Extract substring before the first '_'
        df = pd.read_csv(file_path)
        dataframes[key] = df

# Now `dataframes` is a dictionary containing all the loaded DataFrames

# %%
for key, df in dataframes.items():
    # Calculate the fraction of correct predictions
    df['fraction_correct'] = df[['prediction0', 'prediction1', 'prediction2', 'prediction3', 'prediction4']].eq(df['class_label'], axis=0).mean(axis=1)

# %%
dataframes['mixtral'][10:20]
# Out:
#     Sentence_id                                               Text  \
# 10        37531                           Why is it on the ballot?
# 11        37571                        And we will protect people.
# 12        37589                          I'll give you an example.
# 13        37593  Take a look at all of the drugs that what we'r...
# 14        37623              On Super Tuesday, you got very lucky.
# 15        37628                And tonight I'm going to make sure.
# 16        37630          Because here's the deal, here's the deal.
# 17        37631  The fact is that everything he's saying so far...
# 18        37643  The wrong guy, the wrong night, at the wrong t...
# 19        37651  You agreed with Bernie Sanders on a plan that ...
#
#    class_label                                             prompt prediction0  \
# 10          No  ### Instruction:\nRead the statement provided ...          No
# 11          No  ### Instruction:\nRead the statement provided ...          No
# 12          No  ### Instruction:\nRead the statement provided ...          No
# 13          No  ### Instruction:\nRead the statement provided ...          No
# 14          No  ### Instruction:\nRead the statement provided ...          No
# 15          No  ### Instruction:\nRead the statement provided ...          No
# 16          No  ### Instruction:\nRead the statement provided ...          No
# 17         Yes  ### Instruction:\nRead the statement provided ...          No
# 18          No  ### Instruction:\nRead the statement provided ...          No
# 19         Yes  ### Instruction:\nRead the statement provided ...         Yes
#
#    prediction1 prediction2 prediction3 prediction4 prediction  \
# 10          No          No          No          No         No
# 11          No          No          No          No         No
# 12          No          No          No          No         No
# 13          No          No          No          No         No
# 14          No          No          No          No         No
# 15          No          No          No          No         No
# 16          No          No          No          No         No
# 17          No          No          No          No         No
# 18          No          No          No          No         No
# 19         Yes         Yes         Yes         Yes        Yes
#
#     fraction_correct
# 10               1.0
# 11               1.0
# 12               1.0
# 13               1.0
# 14               1.0
# 15               1.0
# 16               1.0
# 17               0.0
# 18               1.0
# 19               1.0

# %%
# Create a new dataframe with only the first 3 columns of dataframes['gemma']
fractions = dataframes['gemma'].iloc[:, :3]
fractions
# Out:
#      Sentence_id                                               Text  \
# 0          37436  He's been a professor for a long time at a gre...
# 1          37440              There's no way they would give it up.
# 2          37463  They're able to charge women more for the same...
# 3          37470  As far as a say is concerned, the people alrea...
# 4          37504               I am the Democratic Party right now.
# ..           ...                                                ...
# 313        40950  We had the best Black unemployment numbers in ...
# 314        40954             Success is going to bring us together.
# 315        40960  Your 401K's will go to hell and it'll be a ver...
# 316        40971  We're going to choose to move forward because ...
# 317        40972                          We can grow this economy.
#
#     class_label
# 0            No
# 1            No
# 2           Yes
# 3            No
# 4            No
# ..          ...
# 313         Yes
# 314          No
# 315          No
# 316          No
# 317          No
#
# [318 rows x 3 columns]

# %%
for key, df in dataframes.items():
    fractions[f'{key}_fractions_correct'] = df['fraction_correct']

# %%
# Number of complete misclassifications @5
below_one_counts = {
    'llama_non_perfect': (fractions['llama_fractions_correct'] < 1.0).sum().item(),
    'mixtral_non_perfect': (fractions['mixtral_fractions_correct'] < 1.0).sum().item(),
    'gemma_non_perfect': (fractions['gemma_fractions_correct'] < 1.0).sum().item()
}
below_one_counts
# Out:
# {'llama_non_perfect': 36, 'mixtral_non_perfect': 41, 'gemma_non_perfect': 37}

# %%
# Number of rows where at least n models have a misclassification
n = 1
filtered_rows = fractions[(fractions[['llama_fractions_correct', 'mixtral_fractions_correct', 'gemma_fractions_correct']] < 1).sum(axis=1) >= n]
filtered_rows
# Out:
#      Sentence_id                                               Text  \
# 17         37631  The fact is that everything he's saying so far...
# 20         37664                       He has never offered a plan.
# 37         37777  I laid out back in March, exactly what we shou...
# 40         37802  Many of your Democrat Governors said, \Preside...
# 53         37971                 He wants to shut down the country.
# 57         38023                       Dr. Fauci said the opposite.
# 58         38075  He's been totally irresponsible the way in whi...
# 64         38156  Because it costs a lot of money to open them s...
# 80         38294  And plenty of companies that are already here,...
# 87         38510  He came out of his bunker, had the military us...
# 89         38513  The general who was with him said All he ever ...
# 91         38562  There's systemic injustice in this country, in...
# 95         38599  And if you look at the people, we would pay pe...
# 103        38666  The places we had trouble were Democratic-run ...
# 105        38675  The numbers are going up a 100, 150, 200 perce...
# 117        38882  With regard to being weaker, the fact is that ...
# 120        38913                             He spent a year there.
# 130        39037  Making sure that we can do that, we're going t...
# 135        39105                            Yeah, you did say that.
# 136        39120               So why didn't he do it for 47 years?
# 138        39132               The Green New Deal is not my plan...
# 142        39198  And this is all about trying to dissuade peopl...
# 152        39353             ... sent in and swamping the system...
# 153        39373            In Philadelphia, they went in to watch.
# 155        39394           It means you have a fraudulent election.
# 157        39414  And by the way, our military--they've been vot...
# 161        39479  You see the spikes in Europe and many other pl...
# 170        39514  And we're in a circumstance where the Presiden...
# 176        39560  Look, his own person who ran that for him who,...
# 184        39679                  And he supports all these people.
# 186        39697  There's depression, alcohol, drugs at a level ...
# 194        39775  But, guess what, in the meantime, we find out ...
# 205        39840  Your family got three and a half million dolla...
# 207        39848  I sold - while he was selling pillows and shee...
# 209        39851            They took over the, the submarine port.
# 210        39856  They were paying you a lot of money and they p...
# 213        39876        The foreign countries are paying you a lot.
# 215        39895                          So, I already prepaid it.
# 216        39902  Number two, I don't make money from China, you...
# 218        39910  Your son said we have to give 10% to the big man.
# 221        39940  I was put through a phony witch hunt for three...
# 224        39994  Excuse me, and then unlike him, where he's Vic...
# 228        40034                     First of all, China is paying.
# 235        40152  The individual mandate -- where you have to pa...
# 236        40153                        I terminated it; it's gone.
# 246        40218  Excuse me, he was there for 47 years - he didn...
# 247        40245  And they're going to have lower premiums, you ...
# 253        40313  And it's gone through, including the Democrats...
# 259        40356  They allowed the federal government to deficit...
# 265        40422  But a lot of these kids come out without the p...
# 269        40464  And the fact is, I've made it very clear, with...
# 277        40585  The fact of the matter is, in 2000 though, aft...
# 299        40792  We're going to be in a position where we're go...
# 302        40831           He thinks wind causes cancer, windmills.
# 309        40889  We saved our oil industry and now it's very vi...
# 311        40917  You won't give federal subsidies to the gas an...
#
#     class_label  llama_fractions_correct  mixtral_fractions_correct  \
# 17          Yes                      0.4                        0.0
# 20          Yes                      1.0                        1.0
# 37           No                      1.0                        0.8
# 40          Yes                      1.0                        0.4
# 53          Yes                      0.0                        0.0
# 57          Yes                      1.0                        0.6
# 58          Yes                      0.8                        0.8
# 64          Yes                      0.0                        0.0
# 80          Yes                      0.0                        0.0
# 87          Yes                      0.8                        1.0
# 89          Yes                      0.2                        0.4
# 91          Yes                      0.0                        0.0
# 95           No                      1.0                        0.8
# 103         Yes                      0.6                        0.6
# 105         Yes                      0.0                        1.0
# 117         Yes                      1.0                        0.4
# 120          No                      1.0                        0.6
# 130          No                      0.8                        1.0
# 135         Yes                      0.0                        0.0
# 136         Yes                      0.0                        0.0
# 138         Yes                      0.0                        0.6
# 142         Yes                      0.0                        0.0
# 152          No                      1.0                        1.0
# 153          No                      1.0                        0.8
# 155         Yes                      0.0                        0.0
# 157         Yes                      1.0                        1.0
# 161         Yes                      0.6                        0.0
# 170         Yes                      0.6                        1.0
# 176         Yes                      1.0                        0.6
# 184         Yes                      0.4                        0.6
# 186         Yes                      0.4                        1.0
# 194         Yes                      0.0                        1.0
# 205         Yes                      0.0                        0.0
# 207         Yes                      1.0                        1.0
# 209         Yes                      0.8                        1.0
# 210         Yes                      1.0                        0.2
# 213         Yes                      1.0                        0.6
# 215         Yes                      0.0                        0.0
# 216         Yes                      0.6                        0.4
# 218         Yes                      0.2                        0.2
# 221         Yes                      0.4                        0.2
# 224          No                      1.0                        0.8
# 228         Yes                      0.4                        0.4
# 235         Yes                      0.2                        0.0
# 236         Yes                      1.0                        0.8
# 246         Yes                      0.8                        1.0
# 247          No                      1.0                        1.0
# 253         Yes                      0.8                        0.0
# 259         Yes                      1.0                        0.6
# 265         Yes                      0.4                        1.0
# 269          No                      0.0                        0.0
# 277         Yes                      1.0                        1.0
# 299          No                      0.0                        0.2
# 302         Yes                      0.0                        0.0
# 309         Yes                      1.0                        0.6
# 311          No                      0.0                        0.2
#
#      gemma_fractions_correct
# 17                       0.8
# 20                       0.6
# 37                       1.0
# 40                       0.2
# 53                       0.0
# 57                       1.0
# 58                       0.2
# 64                       0.0
# 80                       0.0
# 87                       1.0
# 89                       0.2
# 91                       0.4
# 95                       1.0
# 103                      1.0
# 105                      1.0
# 117                      0.0
# 120                      1.0
# 130                      1.0
# 135                      0.0
# 136                      0.0
# 138                      0.0
# 142                      0.6
# 152                      0.4
# 153                      1.0
# 155                      0.0
# 157                      0.8
# 161                      1.0
# 170                      0.6
# 176                      0.8
# 184                      0.6
# 186                      0.8
# 194                      1.0
# 205                      0.0
# 207                      0.8
# 209                      1.0
# 210                      1.0
# 213                      1.0
# 215                      0.8
# 216                      0.2
# 218                      0.0
# 221                      0.0
# 224                      1.0
# 228                      0.2
# 235                      0.0
# 236                      1.0
# 246                      0.2
# 247                      0.8
# 253                      0.8
# 259                      0.6
# 265                      1.0
# 269                      0.2
# 277                      0.6
# 299                      1.0
# 302                      0.0
# 309                      1.0
# 311                      0.8

# %%
filtered_rows.to_csv('results/filtered.csv', index=False)

# %%
import plotly.graph_objects as go
# Create a 3D scatter plot
fig = go.Figure(data=[go.Scatter3d(
    x=x,
    y=y,
    z=z,
    mode='markers',
    marker=dict(
        size=5,
        color='blue',
        opacity=0.8
    )
)])

fig.update_layout(height=500)
# Set labels
fig.update_layout(
    scene=dict(
        xaxis_title='Llama',
        yaxis_title='Mixtral',
        zaxis_title='Gemma'
    ),
    title='Interactive 3D Scatter Plot'
)

# Show the plot
fig.show()
